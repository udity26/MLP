# %%
import pandas as pd

# %%
# Load csv file in jupyter notebook

df=pd.read_csv('Desktop/spotify.csv')
df
# Out:
#      Pos   P+          Artist                 Title  Wks   Pk   (x?)  \
# 0      1   +4            SZA              Kill Bill    4    1   (x1)
# 1      2   +9      Sam Smith                 Unholy   15    1   (x7)
# 2      3  +12   Harry Styles              As It Was   40    1  (x11)
# 3      4  +16   David Guetta        I'm Good (Blue)   19    2   (x4)
# 4      5   +8   Metro Boomin               Creepin'    5    3   (x1)
# ..   ...  ...             ...                   ...  ...  ...    ...
# 195  196   RE      Bad Bunny                  Party   33    6    NaN
# 196  197   RE  Freddie Dredd                  Limbo    7  158    NaN
# 197  198   RE     Bruno Mars   Locked Out Of Heaven   82   45    NaN
# 198  199   RE         MEDUZA           Bad Memories    2  199    NaN
# 199  200   RE        TWISTED          WORTH NOTHING    5  181    NaN
#
#       Streams   Streams+       Total
# 0    41474366  1578141.0   160755788
# 1    33132175  2872164.0   642800599
# 2    30998084  3982809.0  1719435686
# 3    30704256  7144547.0   541637842
# 4    28092232   381484.0   153469486
# ..        ...        ...         ...
# 195   6782777        NaN   479414025
# 196   6775767        NaN    51408912
# 197   6758678        NaN   335046675
# 198   6748442        NaN    13244341
# 199   6735908        NaN    34008257
#
# [200 rows x 10 columns]

# %%
#Q1:  Fetch data from paticular column as : row(1) , column(1) 

df.loc[1]
# Out:
# Pos                  2
# P+                  +9
# Artist      Sam Smith
# Title           Unholy
# Wks                 15
# Pk                   1
# (x?)              (x7)
# Streams       33132175
# Streams+     2872164.0
# Total        642800599
# Name: 1, dtype: object

# %%
#Q2: Print length of rows

len(df)
# Out:
# 200

# %%
# Q3: Print first 4 records of dataset  
df.head(4)
# Out:
#    Pos   P+         Artist            Title  Wks  Pk   (x?)   Streams  \
# 0    1   +4           SZA         Kill Bill    4   1   (x1)  41474366
# 1    2   +9     Sam Smith            Unholy   15   1   (x7)  33132175
# 2    3  +12  Harry Styles         As It Was   40   1  (x11)  30998084
# 3    4  +16  David Guetta   I'm Good (Blue)   19   2   (x4)  30704256
#
#     Streams+       Total
# 0  1578141.0   160755788
# 1  2872164.0   642800599
# 2  3982809.0  1719435686
# 3  7144547.0   541637842

# %%
# Q4: First starting records of dataset  
# That will be generated randomly 

df.head()
# Out:
#    Pos   P+         Artist            Title  Wks  Pk   (x?)   Streams  \
# 0    1   +4           SZA         Kill Bill    4   1   (x1)  41474366
# 1    2   +9     Sam Smith            Unholy   15   1   (x7)  33132175
# 2    3  +12  Harry Styles         As It Was   40   1  (x11)  30998084
# 3    4  +16  David Guetta   I'm Good (Blue)   19   2   (x4)  30704256
# 4    5   +8  Metro Boomin          Creepin'    5   3   (x1)  28092232
#
#     Streams+       Total
# 0  1578141.0   160755788
# 1  2872164.0   642800599
# 2  3982809.0  1719435686
# 3  7144547.0   541637842
# 4   381484.0   153469486

# %%
# Q5: Print last records of dataset  

df.tail(2)
# Out:
#      Pos  P+    Artist          Title  Wks   Pk (x?)  Streams  Streams+  \
# 198  199  RE   MEDUZA    Bad Memories    2  199  NaN  6748442       NaN
# 199  200  RE  TWISTED   WORTH NOTHING    5  181  NaN  6735908       NaN
#
#         Total
# 198  13244341
# 199  34008257

# %%
#Q6: Fetch records of all Booking_ID

df.Artist
# Out:
# 0                SZA
# 1          Sam Smith
# 2       Harry Styles
# 3       David Guetta
# 4       Metro Boomin
#             ...
# 195        Bad Bunny
# 196    Freddie Dredd
# 197       Bruno Mars
# 198           MEDUZA
# 199          TWISTED
# Name: Artist, Length: 200, dtype: object

# %%
#Q7: Print First starting records from column Booking_ID of dataset  

df.Artist.head()
# Out:
# 0             SZA
# 1       Sam Smith
# 2    Harry Styles
# 3    David Guetta
# 4    Metro Boomin
# Name: Artist, dtype: object

# %%
#Q7: Print first 2 records which have lead_time greater than 80

df.query('Wks > 80').head(2)
# Out:
#     Pos   P+          Artist         Title  Wks  Pk   (x?)   Streams  \
# 17   18  +23      Tom Odell   Another Love   91  15    NaN  18813633
# 35   36  +34  Glass Animals     Heat Waves  106   1  (x10)  15069567
#
#      Streams+       Total
# 17   980197.0   941132332
# 35  2194862.0  2096035997

# %%
#Q8 : Print all the columns name

df.columns
# Out:
# Index(['Pos', 'P+', 'Artist', 'Title', 'Wks', 'Pk', '(x?)', 'Streams',
#        'Streams+', 'Total'],
#       dtype='object')

# %%
#Q9 : Print the column name , index should be 2

df.columns[2]
# Out:
# 'Artist'

# %%
#10: Fetch the records of rows at 0,3,5.

df.loc[[0,3,5]]
# Out:
#    Pos   P+          Artist            Title  Wks  Pk  (x?)   Streams  \
# 0    1   +4            SZA         Kill Bill    4   1  (x1)  41474366
# 3    4  +16   David Guetta   I'm Good (Blue)   19   2  (x4)  30704256
# 5    6  +10  Manuel Turizo        La Bachata   27   4   NaN  27357095
#
#     Streams+      Total
# 0  1578141.0  160755788
# 3  7144547.0  541637842
# 5   727736.0  667941457
